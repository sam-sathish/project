# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
TE=pd.read_csv("C:\\Users\\aedpu\\Downloads\\student-dataset.csv")

# %%
TE
# Out:
#     age  english.grade  math.grade  sciences.grade  language.grade
# 0    22            3.5         3.7             3.1               1
# 1    22            2.9         3.2             3.6               5
# 2    22            3.9         3.8             3.2               5
# 3    20            3.3         2.8             3.2               5
# 4    21            3.7         2.6             3.4               1
# ..  ...            ...         ...             ...             ...
# 74   21            2.3         3.7             3.6               5
# 75   21            3.2         2.6             3.0               5
# 76   21            3.5         3.9             3.4               4
# 77   23            3.5         3.1             4.0               4
# 78   23            3.1         2.5             3.7               5
#
# [79 rows x 5 columns]

# %%
TE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             79 non-null     int64
#  1   english.grade   79 non-null     float64
#  2   math.grade      79 non-null     float64
#  3   sciences.grade  79 non-null     float64
#  4   language.grade  79 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 3.2 KB

# %%
newdataset=TE.drop(['age','math.grade','sciences.grade'],axis=1)

# %%
newdataset
# Out:
#     english.grade  language.grade
# 0             3.5               1
# 1             2.9               5
# 2             3.9               5
# 3             3.3               5
# 4             3.7               1
# ..            ...             ...
# 74            2.3               5
# 75            3.2               5
# 76            3.5               4
# 77            3.5               4
# 78            3.1               5
#
# [79 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[3.5],
#        [2.9],
#        [3.9],
#        [3.3],
#        [3.7],
#        [3.4],
#        [3.7],
#        [3.8],
#        [3.9],
#        [2.4],
#        [3.4],
#        [1.7],
#        [3.8],
#        [3.7],
#        [3.2],
#        [4. ],
#        [2.9],
#        [3.1],
#        [3.9],
#        [3.7],
#        [3.8],
#        [3.9],
#        [3.6],
#        [3.8],
#        [2.8],
#        [3.7],
#        [3.1],
#        [3.9],
#        [3.4],
#        [3.4],
#        [3.4],
#        [2.3],
#        [3.8],
#        [3.4],
#        [3.3],
#        [3.3],
#        [3.7],
#        [3.8],
#        [3.3],
#        [3. ],
#        [3.7],
#        [1.7],
#        [3.9],
#        [3.9],
#        [3.4],
#        [3.6],
#        [2.8],
#        [2.1],
#        [2.3],
#        [3.6],
#        [2.4],
#        [3.2],
#        [3.5],
#        [1.9],
#        [3.9],
#        [2.9],
#        [3.1],
#        [3.5],
#        [2.1],
#        [3.1],
#        [3.9],
#        [3.6],
# ...

# %%
y
# Out:
# array([[1],
#        [5],
#        [5],
#        [5],
#        [1],
#        [5],
#        [2],
#        [2],
#        [2],
#        [3],
#        [5],
#        [5],
#        [5],
#        [4],
#        [5],
#        [3],
#        [5],
#        [4],
#        [5],
#        [5],
#        [2],
#        [2],
#        [5],
#        [2],
#        [4],
#        [5],
#        [5],
#        [5],
#        [5],
#        [4],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [3],
#        [3],
#        [4],
#        [5],
#        [4],
#        [5],
#        [2],
#        [4],
#        [4],
#        [5],
#        [5],
#        [4],
#        [5],
#        [5],
#        [2],
#        [1],
#        [5],
#        [2],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [4],
#        [5],
#        [4],
#        [5],
#        [5],
#        [5],
#        [3],
#        [5],
#        [5],
#        [3],
#        [5],
#        [3],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('english.grade')
pt.ylabel('language.grade')
pt.title('student dataset')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
x_train.shape
# Out:
# (63, 1)

# %%
y_test.shape
# Out:
# (16, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[3.86550034],
#        [3.7462427 ],
#        [3.94500543],
#        [4.22327326],
#        [3.86550034],
#        [4.18352071],
#        [4.38228344],
#        [3.90525288],
#        [4.38228344],
#        [3.90525288],
#        [3.82574779],
#        [3.86550034],
#        [3.7462427 ],
#        [3.82574779],
#        [4.06426307],
#        [3.98475798]])

# %%
COMP=pd.DataFrame(x_test,columns=['close'])

# %%
COMP
# Out:
#     close
# 0     3.6
# 1     3.9
# 2     3.4
# 3     2.7
# 4     3.6
# 5     2.8
# 6     2.3
# 7     3.5
# 8     2.3
# 9     3.5
# 10    3.7
# 11    3.6
# 12    3.9
# 13    3.7
# 14    3.1
# 15    3.3

# %%
COMP['AVLDATA']=y_test

# %%
COMP
# Out:
#     close  AVLDATA
# 0     3.6        2
# 1     3.9        5
# 2     3.4        5
# 3     2.7        5
# 4     3.6        5
# 5     2.8        5
# 6     2.3        5
# 7     3.5        4
# 8     2.3        5
# 9     3.5        5
# 10    3.7        5
# 11    3.6        5
# 12    3.9        5
# 13    3.7        5
# 14    3.1        5
# 15    3.3        5

# %%
COMP['PRDDATA']=y_test

# %%
COMP
# Out:
#     close  AVLDATA  PRDDATA
# 0     3.6        2        2
# 1     3.9        5        5
# 2     3.4        5        5
# 3     2.7        5        5
# 4     3.6        5        5
# 5     2.8        5        5
# 6     2.3        5        5
# 7     3.5        4        4
# 8     2.3        5        5
# 9     3.5        5        5
# 10    3.7        5        5
# 11    3.6        5        5
# 12    3.9        5        5
# 13    3.7        5        5
# 14    3.1        5        5
# 15    3.3        5        5

# %%
pt.scatter(x,y,color='purple')
pt.plot(x_test,y_predict,color='black')
pt.xlabel('english.grade')
pt.ylabel('language.grade')
pt.title('student dataset')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 1.1384808659969758

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 1.0009140994217278

# %%
r2_score(y_test,y_predict)
# Out:
# -1.0239659839946236

# %%
lm.score(x_test,y_test)
# Out:
# -1.0239659839946236
